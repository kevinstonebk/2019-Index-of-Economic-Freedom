# %% [markdown]
# ### 2019 Index of Economic Freedom

# %%
####################################################################
#PROJECT NAME: 2019 Index of Economic Freedom                      #    
#                                                                  #
#                                                                  #                    
#PROGRAM NAME: Unsupervised Economic Project                       #  
#AUTHOR:     Kevin Kluck                                           #
#DATE:       10/4/2020                                             #
#                                                                  #
#Python Version:3.7.6                                              #      
#                                                                  #
#                                                                  #         
#ABSTRACT:Use Unsupervise learning techniques to identify          #
#         clusters in The Index of economic freedom data set.      #
#                                                                  #
####################################################################

# %%
####################################################################
##                                                                ##
##                   Import Libraries                             ##
##                                                                ##
###################################################################

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re
import warnings
from PIL import Image
from scipy.stats import zscore
import os
from sklearn.impute import SimpleImputer
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from scipy.spatial.distance import cdist
import seaborn as sns
# %matplotlib inline
from matplotlib import cm




#import warnings
#warnings.filterwarnings("ignore")

# %% [markdown]
# Special thanks to the Heritage Foundation for putting together this data set.

# %%
##############################
##                          ##
##      Import Data         ##
##                          ##
##############################

df = pd.read_excel("economic_freedom_index2019_data.xlsx")



############# python formating ##################
extra = {'Bold': '\x1b[1m',
        'Underline': '\x1b[4m',
        'Blue': '\x1b[94m',
        'End': '\x1b[0m'}

############## Set seed   #############
seed = 1729

# %%
df.T.head(34)
# Out:
#                                       0        1    \
# CountryID                               1        2
# Country Name                  Afghanistan  Albania
# WEBNAME                       Afghanistan  Albania
# Region                       Asia-Pacific   Europe
# World Rank                            152       52
# Region Rank                            39       27
# 2019 Score                           51.5     66.5
# Property Rights                      19.6     54.8
# Judical Effectiveness                29.6     30.6
# Government Integrity                 25.2     40.4
# Tax Burden                           91.7     86.3
# Gov't Spending                       80.3     73.9
# Fiscal Health                        99.3     80.6
# Business Freedom                     49.2     69.3
# Labor Freedom                        60.4     52.7
# Monetary Freedom                     76.7     81.5
# Trade Freedom                          66     87.8
# Investment Freedom                     10       70
# Financial Freedom                      10       70
# Tariff Rate (%)                         7      1.1
# Income Tax Rate (%)                    20       23
# Corporate Tax Rate (%)                 20       15
# Tax Burden % of GDP                     5     24.9
# Gov't Expenditure % of GDP           25.6     29.5
# Country                       Afghanistan  Albania
# Population (Millions)                35.5      2.9
# GDP (Billions, PPP)                  69.6       36
# GDP Growth Rate (%)                   2.5      3.9
# 5 Year GDP Growth Rate (%)            2.9      2.5
# GDP per Capita (PPP)                 1958    12507
# Unemployment (%)                      8.8     13.9
# Inflation (%)                           5        2
# FDI Inflow (Millions)                53.9   1119.1
# Public Debt (% of GDP)                7.3     71.2
#
#                                                       2                   3    \
# CountryID                                               3                   4
# Country Name                                      Algeria              Angola
# WEBNAME                                           Algeria              Angola
# Region                       Middle East and North Africa  Sub-Saharan Africa
# World Rank                                            171                 156
# Region Rank                                            14                  33
# 2019 Score                                           46.2                50.6
# Property Rights                                      31.6                35.9
# Judical Effectiveness                                36.2                26.6
# Government Integrity                                 28.9                20.5
# Tax Burden                                           76.4                83.9
# Gov't Spending                                       48.7                80.7
# Fiscal Health                                        18.7                58.2
# Business Freedom                                     61.6                55.7
# Labor Freedom                                        49.9                58.8
# Monetary Freedom                                     74.9                55.4
# Trade Freedom                                        67.4                61.2
# Investment Freedom                                     30                  30
# Financial Freedom                                      30                  40
# Tariff Rate (%)                                       8.8                 9.4
# Income Tax Rate (%)                                    35                  17
# Corporate Tax Rate (%)                                 23                  30
# Tax Burden % of GDP                                  24.5                20.6
# Gov't Expenditure % of GDP                           41.4                25.3
# Country                                           Algeria              Angola
# Population (Millions)                                41.5                28.2
# GDP (Billions, PPP)                                 632.9               190.3
# GDP Growth Rate (%)                                     2                 0.7
# 5 Year GDP Growth Rate (%)                            3.1                 2.9
# GDP per Capita (PPP)                                15237                6753
# Unemployment (%)                                       10                 8.2
# Inflation (%)                                         5.6                31.7
# FDI Inflow (Millions)                                1203             -2254.5
# Public Debt (% of GDP)                               25.8                65.3
#
#                                    4        5             6        7    \
# CountryID                            5        6             7        8
# Country Name                 Argentina  Armenia     Australia  Austria
# WEBNAME                      Argentina  Armenia     Australia  Austria
# Region                        Americas   Europe  Asia-Pacific   Europe
# World Rank                         148       47             5       31
# Region Rank                         26       24             4       16
# 2019 Score                        52.2     67.7          80.9       72
# Property Rights                   47.8     57.2          79.1     84.2
# Judical Effectiveness             44.5     46.3          86.5     71.3
# Government Integrity              33.5     38.6          79.9     77.4
# Tax Burden                        69.3     84.7          62.8     50.5
# Gov't Spending                    49.5       79          60.1     24.5
# Fiscal Health                       33       53          86.2     85.5
# Business Freedom                  56.4     78.3          88.3     74.9
# Labor Freedom                     46.9     71.4          84.1     68.7
# Monetary Freedom                  60.2     77.8          86.6     81.5
# Trade Freedom                       70     80.8          87.6       86
# Investment Freedom                  55       75            80       90
# Financial Freedom                   60       70            90       70
# Tariff Rate (%)                    7.5      2.1           1.2        2
# Income Tax Rate (%)                 35       26            45       50
# Corporate Tax Rate (%)              30       20            30       25
# Tax Burden % of GDP               30.8     21.3          28.2     42.7
# Gov't Expenditure % of GDP          41     26.4          36.5     50.2
# Country                      Argentina  Armenia     Australia  Austria
# Population (Millions)             44.1        3          24.8      8.8
# GDP (Billions, PPP)              920.2     28.3        1246.5    439.6
# GDP Growth Rate (%)                2.9      7.5           2.3      2.9
# 5 Year GDP Growth Rate (%)         0.7      3.6           2.4      1.3
# GDP per Capita (PPP)             20876     9456         50334    49869
# Unemployment (%)                   8.7     18.2           5.6      5.5
# Inflation (%)                     25.7      0.9             2      2.2
# FDI Inflow (Millions)            11857    245.7         46368   9629.6
# Public Debt (% of GDP)            52.6     53.5          41.6     78.8
#
#                                       8         9    ...             176  \
# CountryID                               9        10  ...             174
# Country Name                   Azerbaijan   Bahamas  ...  United Kingdom
# WEBNAME                        Azerbaijan   Bahamas  ...   UnitedKingdom
# Region                       Asia-Pacific  Americas  ...          Europe
# World Rank                             60        76  ...               7
# Region Rank                            13        15  ...               3
# 2019 Score                           65.4      62.9  ...            78.9
# Property Rights                      59.1      42.2  ...            92.3
# Judical Effectiveness                53.1      46.9  ...            85.9
# Government Integrity                 44.7      43.7  ...            83.8
# Tax Burden                           87.5      97.3  ...            64.7
# Gov't Spending                       59.5      86.8  ...            48.2
# Fiscal Health                        89.4      65.7  ...            68.6
# Business Freedom                     69.5      68.5  ...            92.9
# Labor Freedom                        63.9      67.5  ...            73.5
# Monetary Freedom                       63      78.1  ...            81.2
# Trade Freedom                        74.6      47.8  ...              86
# Investment Freedom                     60        50  ...              90
# Financial Freedom                      60        60  ...              80
# Tariff Rate (%)                       5.2      18.6  ...               2
# Income Tax Rate (%)                    25         0  ...              45
# Corporate Tax Rate (%)                 20         0  ...              20
# Tax Burden % of GDP                    15      16.3  ...            33.2
# Gov't Expenditure % of GDP           36.7        21  ...            41.6
# Country                        Azerbaijan   Bahamas  ...  United Kingdom
# Population (Millions)                 9.8       0.4  ...            66.1
# GDP (Billions, PPP)                 171.8      11.6  ...            2914
# GDP Growth Rate (%)                   0.1       1.3  ...             1.8
# 5 Year GDP Growth Rate (%)            1.2      -0.7  ...             2.2
# GDP per Capita (PPP)                17492     31139  ...           44118
# Unemployment (%)                        5      12.6  ...             4.3
# Inflation (%)                          13       1.4  ...             2.7
# FDI Inflow (Millions)                2867     927.7  ...           15090
# Public Debt (% of GDP)               54.7      57.2  ...              87
#
#                                        177       178           179  \
# CountryID                              175       176           177
# Country Name                 United States   Uruguay    Uzbekistan
# WEBNAME                       UnitedStates   Uruguay    Uzbekistan
# Region                            Americas  Americas  Asia-Pacific
# World Rank                              12        40           140
# Region Rank                              2         6            36
# 2019 Score                            76.8      68.6          53.3
# Property Rights                       79.3      68.3          49.8
# Judical Effectiveness                 78.6      58.9          34.3
# Government Integrity                  77.4      69.2          25.2
# Tax Burden                            75.1      77.2          91.3
# Gov't Spending                        57.1      67.5          67.4
# Fiscal Health                         53.1      69.9          98.7
# Business Freedom                      83.8      74.3          72.5
# Labor Freedom                         89.4      71.9          58.7
# Monetary Freedom                      76.6      72.9          58.9
# Trade Freedom                         86.6      78.6          62.6
# Investment Freedom                      85        85            10
# Financial Freedom                       80        30            10
# Tariff Rate (%)                        1.7       5.7           8.7
# Income Tax Rate (%)                     37        30            22
# Corporate Tax Rate (%)                  21        25           7.5
# Tax Burden % of GDP                     26      27.4          18.2
# Gov't Expenditure % of GDP            37.8      32.9            33
# Country                      United States   Uruguay    Uzbekistan
# Population (Millions)                325.9       3.5          32.1
# GDP (Billions, PPP)                19390.6      78.1         222.6
# GDP Growth Rate (%)                    2.3       3.1           5.3
# 5 Year GDP Growth Rate (%)             2.2       2.6           7.4
# GDP per Capita (PPP)                 59501     22371          6929
# Unemployment (%)                       4.4       7.9           7.2
# Inflation (%)                          2.1       6.2          12.5
# FDI Inflow (Millions)               275381    -124.6          95.8
# Public Debt (% of GDP)               107.8      66.2          24.5
#
#                                       180        181           182  \
# CountryID                             178        179           180
# Country Name                      Vanuatu  Venezuela       Vietnam
# WEBNAME                           Vanuatu  Venezuela       Vietnam
# Region                       Asia-Pacific   Americas  Asia-Pacific
# World Rank                            116        179           128
# Region Rank                            26         32            30
# 2019 Score                           56.4       25.9          55.3
# Property Rights                      65.9        7.6          49.8
# Judical Effectiveness                36.4       13.1          40.3
# Government Integrity                 51.9        7.9            34
# Tax Burden                           97.3       74.7          79.7
# Gov't Spending                       54.1       58.1          74.1
# Fiscal Health                        15.3       17.6          40.7
# Business Freedom                     52.4       33.9          63.5
# Labor Freedom                        58.8         28          62.8
# Monetary Freedom                       75          0          68.9
# Trade Freedom                        64.4         60          79.2
# Investment Freedom                     65          0            30
# Financial Freedom                      40         10            40
# Tariff Rate (%)                       7.8         10           2.9
# Income Tax Rate (%)                     0         34            35
# Corporate Tax Rate (%)                  0         34            22
# Tax Burden % of GDP                  16.3       14.9            18
# Gov't Expenditure % of GDP           39.1       37.4          29.4
# Country                           Vanuatu  Venezuela       Vietnam
# Population (Millions)                 0.3       31.4          93.6
# GDP (Billions, PPP)                   0.8      380.7         647.4
# GDP Growth Rate (%)                   4.2        -14           6.8
# 5 Year GDP Growth Rate (%)            2.4       -7.8           6.2
# GDP per Capita (PPP)                 2739      12114          6913
# Unemployment (%)                      5.2        7.7           2.1
# Inflation (%)                         3.1     1087.5           3.5
# FDI Inflow (Millions)                24.7        -68         14100
# Public Debt (% of GDP)               48.4       34.9          58.2
#
#                                                       183                 184  \
# CountryID                                             181                 182
# Country Name                                        Yemen              Zambia
# WEBNAME                                             Yemen              Zambia
# Region                       Middle East and North Africa  Sub-Saharan Africa
# World Rank                                            NaN                 138
# Region Rank                                           NaN                  27
# 2019 Score                                            NaN                53.6
# Property Rights                                      19.6                  45
# Judical Effectiveness                                22.2                35.6
# Government Integrity                                 20.3                32.3
# Tax Burden                                            NaN                72.3
# Gov't Spending                                       83.7                80.1
# Fiscal Health                                           0                12.3
# Business Freedom                                     45.1                71.1
# Labor Freedom                                        49.8                  46
# Monetary Freedom                                     61.5                70.3
# Trade Freedom                                        71.4                72.6
# Investment Freedom                                     50                  55
# Financial Freedom                                     NaN                  50
# Tariff Rate (%)                                       4.3                 6.2
# Income Tax Rate (%)                                   NaN                  35
# Corporate Tax Rate (%)                                NaN                  35
# Tax Burden % of GDP                                   NaN                17.9
# Gov't Expenditure % of GDP                            NaN                25.8
# Country                                             Yemen              Zambia
# Population (Millions)                                  30                17.2
# GDP (Billions, PPP)                                  38.6                68.9
# GDP Growth Rate (%)                                 -13.8                 3.6
# 5 Year GDP Growth Rate (%)                          -16.1                   4
# GDP per Capita (PPP)                                 1287                3996
# Unemployment (%)                                       14                 7.8
# Inflation (%)                                         4.9                 6.6
# FDI Inflow (Millions)                              -269.9              1091.2
# Public Debt (% of GDP)                                141                62.2
#
#                                             185
# CountryID                                   183
# Country Name                           Zimbabwe
# WEBNAME                                Zimbabwe
# Region                       Sub-Saharan Africa
# World Rank                                  175
# Region Rank                                  45
# 2019 Score                                 40.4
# Property Rights                            29.7
# Judical Effectiveness                      24.8
# Government Integrity                       15.8
# Tax Burden                                 62.3
# Gov't Spending                             74.5
# Fiscal Health                              23.7
# Business Freedom                           33.4
# Labor Freedom                              43.3
# Monetary Freedom                           72.4
# Trade Freedom                                70
# Investment Freedom                           25
# Financial Freedom                            10
# Tariff Rate (%)                               5
# Income Tax Rate (%)                        51.5
# Corporate Tax Rate (%)                       25
# Tax Burden % of GDP                        22.3
# Gov't Expenditure % of GDP                 29.2
# Country                                Zimbabwe
# Population (Millions)                      14.9
# GDP (Billions, PPP)                          34
# GDP Growth Rate (%)                           3
# 5 Year GDP Growth Rate (%)                  2.6
# GDP per Capita (PPP)                       2283
# Unemployment (%)                              5
# Inflation (%)                               1.3
# FDI Inflow (Millions)                     289.4
# Public Debt (% of GDP)                     78.4
#
# [34 rows x 186 columns]

# %% [markdown]
# Country Name, WEBNAME, and Country are referencing the same thing, so drop country name and webname and move country variable to second position of the data set.

# %%
drop_colums = ['Country Name','WEBNAME']
data = df.drop(columns=drop_colums)

# %%
first_col = data.pop('Country')
data.insert(1, 'Country', first_col)
data.T.head(32)
# Out:
#                                       0        1    \
# CountryID                               1        2
# Country                       Afghanistan  Albania
# Region                       Asia-Pacific   Europe
# World Rank                            152       52
# Region Rank                            39       27
# 2019 Score                           51.5     66.5
# Property Rights                      19.6     54.8
# Judical Effectiveness                29.6     30.6
# Government Integrity                 25.2     40.4
# Tax Burden                           91.7     86.3
# Gov't Spending                       80.3     73.9
# Fiscal Health                        99.3     80.6
# Business Freedom                     49.2     69.3
# Labor Freedom                        60.4     52.7
# Monetary Freedom                     76.7     81.5
# Trade Freedom                          66     87.8
# Investment Freedom                     10       70
# Financial Freedom                      10       70
# Tariff Rate (%)                         7      1.1
# Income Tax Rate (%)                    20       23
# Corporate Tax Rate (%)                 20       15
# Tax Burden % of GDP                     5     24.9
# Gov't Expenditure % of GDP           25.6     29.5
# Population (Millions)                35.5      2.9
# GDP (Billions, PPP)                  69.6       36
# GDP Growth Rate (%)                   2.5      3.9
# 5 Year GDP Growth Rate (%)            2.9      2.5
# GDP per Capita (PPP)                 1958    12507
# Unemployment (%)                      8.8     13.9
# Inflation (%)                           5        2
# FDI Inflow (Millions)                53.9   1119.1
# Public Debt (% of GDP)                7.3     71.2
#
#                                                       2                   3    \
# CountryID                                               3                   4
# Country                                           Algeria              Angola
# Region                       Middle East and North Africa  Sub-Saharan Africa
# World Rank                                            171                 156
# Region Rank                                            14                  33
# 2019 Score                                           46.2                50.6
# Property Rights                                      31.6                35.9
# Judical Effectiveness                                36.2                26.6
# Government Integrity                                 28.9                20.5
# Tax Burden                                           76.4                83.9
# Gov't Spending                                       48.7                80.7
# Fiscal Health                                        18.7                58.2
# Business Freedom                                     61.6                55.7
# Labor Freedom                                        49.9                58.8
# Monetary Freedom                                     74.9                55.4
# Trade Freedom                                        67.4                61.2
# Investment Freedom                                     30                  30
# Financial Freedom                                      30                  40
# Tariff Rate (%)                                       8.8                 9.4
# Income Tax Rate (%)                                    35                  17
# Corporate Tax Rate (%)                                 23                  30
# Tax Burden % of GDP                                  24.5                20.6
# Gov't Expenditure % of GDP                           41.4                25.3
# Population (Millions)                                41.5                28.2
# GDP (Billions, PPP)                                 632.9               190.3
# GDP Growth Rate (%)                                     2                 0.7
# 5 Year GDP Growth Rate (%)                            3.1                 2.9
# GDP per Capita (PPP)                                15237                6753
# Unemployment (%)                                       10                 8.2
# Inflation (%)                                         5.6                31.7
# FDI Inflow (Millions)                                1203             -2254.5
# Public Debt (% of GDP)                               25.8                65.3
#
#                                    4        5             6        7    \
# CountryID                            5        6             7        8
# Country                      Argentina  Armenia     Australia  Austria
# Region                        Americas   Europe  Asia-Pacific   Europe
# World Rank                         148       47             5       31
# Region Rank                         26       24             4       16
# 2019 Score                        52.2     67.7          80.9       72
# Property Rights                   47.8     57.2          79.1     84.2
# Judical Effectiveness             44.5     46.3          86.5     71.3
# Government Integrity              33.5     38.6          79.9     77.4
# Tax Burden                        69.3     84.7          62.8     50.5
# Gov't Spending                    49.5       79          60.1     24.5
# Fiscal Health                       33       53          86.2     85.5
# Business Freedom                  56.4     78.3          88.3     74.9
# Labor Freedom                     46.9     71.4          84.1     68.7
# Monetary Freedom                  60.2     77.8          86.6     81.5
# Trade Freedom                       70     80.8          87.6       86
# Investment Freedom                  55       75            80       90
# Financial Freedom                   60       70            90       70
# Tariff Rate (%)                    7.5      2.1           1.2        2
# Income Tax Rate (%)                 35       26            45       50
# Corporate Tax Rate (%)              30       20            30       25
# Tax Burden % of GDP               30.8     21.3          28.2     42.7
# Gov't Expenditure % of GDP          41     26.4          36.5     50.2
# Population (Millions)             44.1        3          24.8      8.8
# GDP (Billions, PPP)              920.2     28.3        1246.5    439.6
# GDP Growth Rate (%)                2.9      7.5           2.3      2.9
# 5 Year GDP Growth Rate (%)         0.7      3.6           2.4      1.3
# GDP per Capita (PPP)             20876     9456         50334    49869
# Unemployment (%)                   8.7     18.2           5.6      5.5
# Inflation (%)                     25.7      0.9             2      2.2
# FDI Inflow (Millions)            11857    245.7         46368   9629.6
# Public Debt (% of GDP)            52.6     53.5          41.6     78.8
#
#                                       8         9    ...             176  \
# CountryID                               9        10  ...             174
# Country                        Azerbaijan   Bahamas  ...  United Kingdom
# Region                       Asia-Pacific  Americas  ...          Europe
# World Rank                             60        76  ...               7
# Region Rank                            13        15  ...               3
# 2019 Score                           65.4      62.9  ...            78.9
# Property Rights                      59.1      42.2  ...            92.3
# Judical Effectiveness                53.1      46.9  ...            85.9
# Government Integrity                 44.7      43.7  ...            83.8
# Tax Burden                           87.5      97.3  ...            64.7
# Gov't Spending                       59.5      86.8  ...            48.2
# Fiscal Health                        89.4      65.7  ...            68.6
# Business Freedom                     69.5      68.5  ...            92.9
# Labor Freedom                        63.9      67.5  ...            73.5
# Monetary Freedom                       63      78.1  ...            81.2
# Trade Freedom                        74.6      47.8  ...              86
# Investment Freedom                     60        50  ...              90
# Financial Freedom                      60        60  ...              80
# Tariff Rate (%)                       5.2      18.6  ...               2
# Income Tax Rate (%)                    25         0  ...              45
# Corporate Tax Rate (%)                 20         0  ...              20
# Tax Burden % of GDP                    15      16.3  ...            33.2
# Gov't Expenditure % of GDP           36.7        21  ...            41.6
# Population (Millions)                 9.8       0.4  ...            66.1
# GDP (Billions, PPP)                 171.8      11.6  ...            2914
# GDP Growth Rate (%)                   0.1       1.3  ...             1.8
# 5 Year GDP Growth Rate (%)            1.2      -0.7  ...             2.2
# GDP per Capita (PPP)                17492     31139  ...           44118
# Unemployment (%)                        5      12.6  ...             4.3
# Inflation (%)                          13       1.4  ...             2.7
# FDI Inflow (Millions)                2867     927.7  ...           15090
# Public Debt (% of GDP)               54.7      57.2  ...              87
#
#                                        177       178           179  \
# CountryID                              175       176           177
# Country                      United States   Uruguay    Uzbekistan
# Region                            Americas  Americas  Asia-Pacific
# World Rank                              12        40           140
# Region Rank                              2         6            36
# 2019 Score                            76.8      68.6          53.3
# Property Rights                       79.3      68.3          49.8
# Judical Effectiveness                 78.6      58.9          34.3
# Government Integrity                  77.4      69.2          25.2
# Tax Burden                            75.1      77.2          91.3
# Gov't Spending                        57.1      67.5          67.4
# Fiscal Health                         53.1      69.9          98.7
# Business Freedom                      83.8      74.3          72.5
# Labor Freedom                         89.4      71.9          58.7
# Monetary Freedom                      76.6      72.9          58.9
# Trade Freedom                         86.6      78.6          62.6
# Investment Freedom                      85        85            10
# Financial Freedom                       80        30            10
# Tariff Rate (%)                        1.7       5.7           8.7
# Income Tax Rate (%)                     37        30            22
# Corporate Tax Rate (%)                  21        25           7.5
# Tax Burden % of GDP                     26      27.4          18.2
# Gov't Expenditure % of GDP            37.8      32.9            33
# Population (Millions)                325.9       3.5          32.1
# GDP (Billions, PPP)                19390.6      78.1         222.6
# GDP Growth Rate (%)                    2.3       3.1           5.3
# 5 Year GDP Growth Rate (%)             2.2       2.6           7.4
# GDP per Capita (PPP)                 59501     22371          6929
# Unemployment (%)                       4.4       7.9           7.2
# Inflation (%)                          2.1       6.2          12.5
# FDI Inflow (Millions)               275381    -124.6          95.8
# Public Debt (% of GDP)               107.8      66.2          24.5
#
#                                       180        181           182  \
# CountryID                             178        179           180
# Country                           Vanuatu  Venezuela       Vietnam
# Region                       Asia-Pacific   Americas  Asia-Pacific
# World Rank                            116        179           128
# Region Rank                            26         32            30
# 2019 Score                           56.4       25.9          55.3
# Property Rights                      65.9        7.6          49.8
# Judical Effectiveness                36.4       13.1          40.3
# Government Integrity                 51.9        7.9            34
# Tax Burden                           97.3       74.7          79.7
# Gov't Spending                       54.1       58.1          74.1
# Fiscal Health                        15.3       17.6          40.7
# Business Freedom                     52.4       33.9          63.5
# Labor Freedom                        58.8         28          62.8
# Monetary Freedom                       75          0          68.9
# Trade Freedom                        64.4         60          79.2
# Investment Freedom                     65          0            30
# Financial Freedom                      40         10            40
# Tariff Rate (%)                       7.8         10           2.9
# Income Tax Rate (%)                     0         34            35
# Corporate Tax Rate (%)                  0         34            22
# Tax Burden % of GDP                  16.3       14.9            18
# Gov't Expenditure % of GDP           39.1       37.4          29.4
# Population (Millions)                 0.3       31.4          93.6
# GDP (Billions, PPP)                   0.8      380.7         647.4
# GDP Growth Rate (%)                   4.2        -14           6.8
# 5 Year GDP Growth Rate (%)            2.4       -7.8           6.2
# GDP per Capita (PPP)                 2739      12114          6913
# Unemployment (%)                      5.2        7.7           2.1
# Inflation (%)                         3.1     1087.5           3.5
# FDI Inflow (Millions)                24.7        -68         14100
# Public Debt (% of GDP)               48.4       34.9          58.2
#
#                                                       183                 184  \
# CountryID                                             181                 182
# Country                                             Yemen              Zambia
# Region                       Middle East and North Africa  Sub-Saharan Africa
# World Rank                                            NaN                 138
# Region Rank                                           NaN                  27
# 2019 Score                                            NaN                53.6
# Property Rights                                      19.6                  45
# Judical Effectiveness                                22.2                35.6
# Government Integrity                                 20.3                32.3
# Tax Burden                                            NaN                72.3
# Gov't Spending                                       83.7                80.1
# Fiscal Health                                           0                12.3
# Business Freedom                                     45.1                71.1
# Labor Freedom                                        49.8                  46
# Monetary Freedom                                     61.5                70.3
# Trade Freedom                                        71.4                72.6
# Investment Freedom                                     50                  55
# Financial Freedom                                     NaN                  50
# Tariff Rate (%)                                       4.3                 6.2
# Income Tax Rate (%)                                   NaN                  35
# Corporate Tax Rate (%)                                NaN                  35
# Tax Burden % of GDP                                   NaN                17.9
# Gov't Expenditure % of GDP                            NaN                25.8
# Population (Millions)                                  30                17.2
# GDP (Billions, PPP)                                  38.6                68.9
# GDP Growth Rate (%)                                 -13.8                 3.6
# 5 Year GDP Growth Rate (%)                          -16.1                   4
# GDP per Capita (PPP)                                 1287                3996
# Unemployment (%)                                       14                 7.8
# Inflation (%)                                         4.9                 6.6
# FDI Inflow (Millions)                              -269.9              1091.2
# Public Debt (% of GDP)                                141                62.2
#
#                                             185
# CountryID                                   183
# Country                                Zimbabwe
# Region                       Sub-Saharan Africa
# World Rank                                  175
# Region Rank                                  45
# 2019 Score                                 40.4
# Property Rights                            29.7
# Judical Effectiveness                      24.8
# Government Integrity                       15.8
# Tax Burden                                 62.3
# Gov't Spending                             74.5
# Fiscal Health                              23.7
# Business Freedom                           33.4
# Labor Freedom                              43.3
# Monetary Freedom                           72.4
# Trade Freedom                                70
# Investment Freedom                           25
# Financial Freedom                            10
# Tariff Rate (%)                               5
# Income Tax Rate (%)                        51.5
# Corporate Tax Rate (%)                       25
# Tax Burden % of GDP                        22.3
# Gov't Expenditure % of GDP                 29.2
# Population (Millions)                      14.9
# GDP (Billions, PPP)                          34
# GDP Growth Rate (%)                           3
# 5 Year GDP Growth Rate (%)                  2.6
# GDP per Capita (PPP)                       2283
# Unemployment (%)                              5
# Inflation (%)                               1.3
# FDI Inflow (Millions)                     289.4
# Public Debt (% of GDP)                     78.4
#
# [32 rows x 186 columns]

# %% [markdown]
# ## Perform univariate analysis

# %%
print(extra['Bold'],extra['Blue'],extra['Underline'],"\nData Types")
print("\n")
print(extra['End'],data.dtypes)

print(extra['Bold'],extra['Blue'],extra['Underline'],"\nShape")
print("\n")
print(extra['End'],data.shape)

print(extra['Bold'],extra['Blue'],extra['Underline'],"\nNumber of Missing Values per Column")
print("\n")
print(extra['End'],data.isnull().sum())

print(extra['Bold'],extra['Blue'],extra['Underline'],"\nNumber of Unique Values per Column")
print("\n")
print(extra['End'],data.nunique())
# Out:
#
# Data Types
#
#
#  CountryID                        int64
# Country                         object
# Region                          object
# World Rank                     float64
# Region Rank                    float64
# 2019 Score                     float64
# Property Rights                float64
# Judical Effectiveness          float64
# Government Integrity           float64
# Tax Burden                     float64
# Gov't Spending                 float64
# Fiscal Health                  float64
# Business Freedom               float64
# Labor Freedom                  float64
# Monetary Freedom               float64
# Trade Freedom                  float64
# Investment Freedom             float64
# Financial Freedom              float64
# Tariff Rate (%)                float64
# Income Tax Rate (%)            float64
# Corporate Tax Rate (%)         float64
# Tax Burden % of GDP            float64
# Gov't Expenditure % of GDP     float64
# Population (Millions)           object
# GDP (Billions, PPP)             object
# GDP Growth Rate (%)            float64
# 5 Year GDP Growth Rate (%)     float64
# GDP per Capita (PPP)            object
# Unemployment (%)                object
# Inflation (%)                  float64
# FDI Inflow (Millions)          float64
# Public Debt (% of GDP)         float64
# dtype: object
#
# Shape
#
#
#  (186, 32)
#
# Number of Missing Values per Column
#
#
#  CountryID                      0
# Country                        0
# Region                         0
# World Rank                     6
# Region Rank                    6
# 2019 Score                     6
# Property Rights                1
# Judical Effectiveness          1
# Government Integrity           1
# Tax Burden                     6
# Gov't Spending                 3
# Fiscal Health                  3
# Business Freedom               1
# Labor Freedom                  2
# Monetary Freedom               2
# Trade Freedom                  4
# Investment Freedom             2
# Financial Freedom              5
# Tariff Rate (%)                4
# Income Tax Rate (%)            3
# Corporate Tax Rate (%)         3
# Tax Burden % of GDP            7
# Gov't Expenditure % of GDP     4
# Population (Millions)          0
# GDP (Billions, PPP)            1
# GDP Growth Rate (%)            2
# 5 Year GDP Growth Rate (%)     3
# GDP per Capita (PPP)           2
# Unemployment (%)               5
# Inflation (%)                  4
# FDI Inflow (Millions)          5
# Public Debt (% of GDP)         4
# dtype: int64
#
# Number of Unique Values per Column
#
#
#  CountryID                      186
# Country                        186
# Region                           5
# World Rank                     180
# Region Rank                     47
# 2019 Score                     138
# Property Rights                128
# Judical Effectiveness          134
# Government Integrity            89
# Tax Burden                     146
# Gov't Spending                 157
# Fiscal Health                  147
# Business Freedom               163
# Labor Freedom                  154
# Monetary Freedom               131
# Trade Freedom                  111
# Investment Freedom              20
# Financial Freedom               10
# Tariff Rate (%)                100
# Income Tax Rate (%)             51
# Corporate Tax Rate (%)          40
# Tax Burden % of GDP            140
# Gov't Expenditure % of GDP     149
# Population (Millions)          139
# GDP (Billions, PPP)            176
# GDP Growth Rate (%)             81
# 5 Year GDP Growth Rate (%)      79
# GDP per Capita (PPP)           184
# Unemployment (%)               107
# Inflation (%)                   87
# FDI Inflow (Millions)          180
# Public Debt (% of GDP)         165
# dtype: int64

# %% [markdown]
# Population, GDP, GDP per Capita, and Unemployment should be numeric.

# %%
data.loc[99] ##### Since most of the variables are missing and 
             #     the info present are from different years. I will remove this observation.
# Out:
# CountryID                                        97
# Country                               Liechtenstein
# Region                                       Europe
# World Rank                                      NaN
# Region Rank                                     NaN
# 2019 Score                                      NaN
# Property Rights                                 NaN
# Judical Effectiveness                           NaN
# Government Integrity                            NaN
# Tax Burden                                      NaN
# Gov't Spending                                  NaN
# Fiscal Health                                   NaN
# Business Freedom                                NaN
# Labor Freedom                                   NaN
# Monetary Freedom                                NaN
# Trade Freedom                                   NaN
# Investment Freedom                               85
# Financial Freedom                                80
# Tariff Rate (%)                                 NaN
# Income Tax Rate (%)                               7
# Corporate Tax Rate (%)                         12.5
# Tax Burden % of GDP                             NaN
# Gov't Expenditure % of GDP                      NaN
# Population (Millions)                   38,000 ppl.
# GDP (Billions, PPP)                $6.1 CHF (2014 )
# GDP Growth Rate (%)                             NaN
# 5 Year GDP Growth Rate (%)                      NaN
# GDP per Capita (PPP)           $139,100 (2009 est.)
# Unemployment (%)                         2.1 (2016)
# Inflation (%)                                   NaN
# FDI Inflow (Millions)                           NaN
# Public Debt (% of GDP)                          NaN
# Name: 99, dtype: object

# %%
data.loc[88] # Drop this observations as well since we have a lot of variables are missing.
# Out:
# CountryID                                      87
# Country                             Korea, North
# Region                               Asia-Pacific
# World Rank                                    180
# Region Rank                                    43
# 2019 Score                                    5.9
# Property Rights                              31.6
# Judical Effectiveness                           5
# Government Integrity                         24.4
# Tax Burden                                      0
# Gov't Spending                                  0
# Fiscal Health                                   0
# Business Freedom                                5
# Labor Freedom                                   5
# Monetary Freedom                                0
# Trade Freedom                                   0
# Investment Freedom                              0
# Financial Freedom                               0
# Tariff Rate (%)                                50
# Income Tax Rate (%)                           NaN
# Corporate Tax Rate (%)                        NaN
# Tax Burden % of GDP                           NaN
# Gov't Expenditure % of GDP                    100
# Population (Millions)                        25.4
# GDP (Billions, PPP)             $40.0 (2015 est.)
# GDP Growth Rate (%)                           1.1
# 5 Year GDP Growth Rate (%)                    NaN
# GDP per Capita (PPP)           $1,700 (2015 est.)
# Unemployment (%)                              4.8
# Inflation (%)                                 NaN
# FDI Inflow (Millions)                        63.4
# Public Debt (% of GDP)                        NaN
# Name: 88, dtype: object

# %%
data = data[data['Country'] != 'Liechtenstein']
data = data[data['Country'] != 'Korea, North ']

# %%
############# Change object variables to numeric #############
change_numeric = ["Population (Millions)", "GDP (Billions, PPP)", "GDP per Capita (PPP)", "Unemployment (%)"]

  
data[change_numeric] = data[change_numeric].apply(pd.to_numeric)

# %%
print(extra['Bold'],extra['Blue'],extra['Underline'],"\nStatistical Summary")
print(extra['End'])
drop_colums = ['Country','CountryID']
data1 = data.drop(columns=drop_colums)
U_df = pd.concat([data1.describe().T, data1.skew()], axis=1)
U_df.rename(columns={0:"Skewed"}, inplace=True)
U_df.sort_values(by = "Skewed")
# Out:
#
# Statistical Summary
#                              count          mean           std     min  \
# Monetary Freedom             183.0     75.484153      9.774244     0.0
# 5 Year GDP Growth Rate (%)   183.0      2.984153      2.926503   -16.1
# Gov't Spending               182.0     64.556593     22.716291     0.0
# Fiscal Health                182.0     66.359341     31.469670     0.0
# Investment Freedom           182.0     57.417582     22.197788     0.0
# Trade Freedom                181.0     74.671271     10.971769    45.0
# Tax Burden                   179.0     77.644134     11.906268    42.0
# Corporate Tax Rate (%)       182.0     23.953846      8.841974     0.0
# Business Freedom             184.0     63.832065     15.237167    17.7
# Income Tax Rate (%)          182.0     28.299451     13.317975     0.0
# Labor Freedom                183.0     59.739891     13.814676    20.0
# Financial Freedom            179.0     48.882682     19.105934    10.0
# 2019 Score                   179.0     61.074860     10.506926    25.9
# World Rank                   179.0     90.000000     51.816986     1.0
# Property Rights              184.0     52.440217     19.601910     7.6
# Region Rank                  179.0     20.413408     12.662296     1.0
# Tax Burden % of GDP          179.0     22.157542     10.152671     1.6
# Judical Effectiveness        184.0     45.116304     17.911627    10.0
# Tariff Rate (%)              181.0      5.743646      4.468672     0.0
# Government Integrity         184.0     41.563043     19.806825     7.9
# Unemployment (%)             179.0      7.440782      5.697384     0.1
# Public Debt (% of GDP)       182.0     56.469231     34.163855     0.0
# GDP per Capita (PPP)         182.0  20757.324176  22358.225141   677.0
# Gov't Expenditure % of GDP   181.0     33.498343     14.711150    10.6
# FDI Inflow (Millions)        180.0   7954.751667  26050.636997 -8296.9
# GDP (Billions, PPP)          183.0    694.233333   2421.728981     0.2
# GDP Growth Rate (%)          183.0      3.483060      5.849090   -14.0
# Population (Millions)        184.0     40.237500    145.547703     0.1
# Inflation (%)                182.0     10.586264     80.507501    -0.9
#
#                                   25%       50%        75%       max  \
# Monetary Freedom               72.100     77.80     81.750      88.0
# 5 Year GDP Growth Rate (%)      1.900      3.00      4.450       9.9
# Gov't Spending                 52.175     68.90     82.900      96.6
# Fiscal Health                  40.775     80.45     91.525     100.0
# Investment Freedom             45.000     60.00     75.000      95.0
# Trade Freedom                  66.800     76.20     84.400      95.0
# Tax Burden                     71.100     78.10     85.450      99.8
# Corporate Tax Rate (%)         20.000     25.00     30.000      50.0
# Business Freedom               54.325     64.70     75.025      96.4
# Income Tax Rate (%)            20.000     30.00     35.000      60.0
# Labor Freedom                  50.900     59.90     68.550      91.0
# Financial Freedom              30.000     50.00     60.000      90.0
# 2019 Score                     54.000     60.80     67.800      90.2
# World Rank                     45.500     90.00    134.500     179.0
# Property Rights                37.000     50.35     65.900      97.4
# Region Rank                     9.500     19.00     30.500      47.0
# Tax Burden % of GDP            14.250     20.70     29.850      47.0
# Judical Effectiveness          31.000     42.90     54.875      92.4
# Tariff Rate (%)                 2.000      4.30      8.700      18.6
# Government Integrity           27.200     35.95     50.300      96.7
# Unemployment (%)                3.750      5.80      9.450      27.3
# Public Debt (% of GDP)         34.950     49.90     70.125     236.4
# GDP per Capita (PPP)         4479.500  12697.50  29509.250  124529.0
# Gov't Expenditure % of GDP     24.500     32.30     40.000     139.2
# FDI Inflow (Millions)         237.725    912.15   4119.750  275381.0
# GDP (Billions, PPP)            25.700     83.60    402.550   23159.1
# GDP Growth Rate (%)             1.850      3.20      4.700      70.8
# Population (Millions)           2.600      8.80     29.625    1390.1
# Inflation (%)                   1.300      2.75      5.450    1087.5
#
#                                 Skewed
# Monetary Freedom             -3.032098
# 5 Year GDP Growth Rate (%)   -2.036546
# Gov't Spending               -0.988389
# Fiscal Health                -0.835254
# Investment Freedom           -0.692252
# Trade Freedom                -0.614310
# Tax Burden                   -0.558881
# Corporate Tax Rate (%)       -0.509089
# Business Freedom             -0.423762
# Income Tax Rate (%)          -0.228213
# Labor Freedom                -0.124343
# Financial Freedom            -0.087940
# 2019 Score                   -0.058944
# World Rank                    0.000000
# Property Rights               0.216552
# Region Rank                   0.244291
# Tax Burden % of GDP           0.393711
# Judical Effectiveness         0.499096
# Tariff Rate (%)               0.934767
# Government Integrity          1.090650
# Unemployment (%)              1.552746
# Public Debt (% of GDP)        1.571366
# GDP per Capita (PPP)          1.912538
# Gov't Expenditure % of GDP    3.149462
# FDI Inflow (Millions)         7.279841
# GDP (Billions, PPP)           7.342324
# GDP Growth Rate (%)           8.139315
# Population (Millions)         8.217533
# Inflation (%)                13.370379

# %% [markdown]
# There are two variables that are highly skewed to the left, Monetary Freedom and 5 Year GDP Growth Rate (%). We also have a handful of variables that skewed to the right as well.

# %%
plt.figure(figsize=(10,6))
sns.countplot(x = data['Region'], order = data['Region'].value_counts().index)
plt.title('Counts by Region')
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4]), <a list of 5 Text major ticklabel objects>)

# %% [markdown]
# Most of the countries are from the Sub-Saharan Africa area, and the least are from the Middle East and North Africa.

# %%
sns.distplot(data['Government Integrity'], hist_kws=dict(edgecolor="k", linewidth=1))
plt.title('Distribution of Government Integrity')
# Out:
# Text(0.5, 1.0, 'Distribution of Government Integrity')

# %% [markdown]
# Most countries appear to have a low government integrity, with the distribution being right skewed.

# %%
sns.distplot(data['Inflation (%)'], hist_kws=dict(edgecolor="k", linewidth=1))
plt.title('Distribution of Inflation (%)')
# Out:
# Text(0.5, 1.0, 'Distribution of Inflation (%)')

# %% [markdown]
# Most countries have very low to no inflation. There appears to be an outlier above 1000 %.

# %%
sns.distplot(data['Population (Millions)'], hist_kws=dict(edgecolor="k", linewidth=1))
plt.title('Distribution of Population (Millions)')
# Out:
# Text(0.5, 1.0, 'Distribution of Population (Millions)')

# %% [markdown]
# Population is highly skewed to the right with a couple of countries as outliers, India and China with populations over a billion.

# %%
sns.distplot(data['Monetary Freedom'], hist_kws=dict(edgecolor="k", linewidth=1))
plt.title('Distribution of Monetary Freedom)')
# Out:
# Text(0.5, 1.0, 'Distribution of Monetary Freedom)')

# %% [markdown]
# Monetary freedom is highly skewed to the left and has few observations with no Monetary Freedom.

# %% [markdown]
# ## Perform bivariate analysis

# %%
drop_colums = ['Country','CountryID', 'Region']
data2 = data.drop(columns=drop_colums)
plt.figure(figsize=(25,15))
sns.heatmap(abs(data2.corr()),annot=True)
plt.show()

# %% [markdown]
# There is some high correlation with world rank, 2019 score, property rights, judicial effectiveness, government integrity, business freedom, trade freedom, investment freedom, and financial freedom. These variables possibly play a huge role in getting a high world ranking. Gov't Expenditure % of GDP and Gov't Spending is highly correlated. Tariff Rate and Trade Freedom is also highly correlated.
#
# Public Debt, FDI inflow, inflation, Unemployment, 5 year GDP growth Rate, GDP Growth Rate, Population in millions and any variable with little correlation with the other variables I will drop to reduce dimensions.

# %%
plt.figure(figsize=(20,10))
plt.title('Distribution of world rank by region')
sns.boxplot(data['Region'], data['World Rank']);

# %% [markdown]
# Mean values seem to be different but for the most part each region has similar ranges in world rank scores.

# %%
plt.figure(figsize=(20,10))
plt.title('Distribution of Population by region')
sns.boxplot(data['Region'], data['Population (Millions)']);

# %% [markdown]
# Asian region has more countries with higher populations but there seems to be an overlap on ranges for each region.

# %%
plt.figure(figsize=(20,10))
plt.title('Distribution of GDP by Property Rights')
sns.boxplot(data['Region'], data['Property Rights']);

# %% [markdown]
# The ranges of property rights overlap each region.

# %%
plt.figure(figsize=(20,10))
plt.title('Distribution of GDP by Property Rights')
sns.boxplot(data['Region'], data['GDP (Billions, PPP)']);

# %% [markdown]
# Asia-Pacific seems to have the upper values for GDP, but for the most part the ranges appear to be about the same.

# %%
plt.figure(figsize=(20,10))
plt.title('Distribution of GDP by region')
sns.boxplot(data['Region'], data['GDP (Billions, PPP)']);

# %% [markdown]
# ### Clean up Data

# %%
#### Deal with missing Data ######
data[data['World Rank'].isnull()].T
# Out:
#                                                       78   \
# CountryID                                              77
# Country                                              Iraq
# Region                       Middle East and North Africa
# World Rank                                            NaN
# Region Rank                                           NaN
# 2019 Score                                            NaN
# Property Rights                                        37
# Judical Effectiveness                                12.3
# Government Integrity                                 20.3
# Tax Burden                                            NaN
# Gov't Spending                                       52.8
# Fiscal Health                                        13.3
# Business Freedom                                     54.4
# Labor Freedom                                        53.1
# Monetary Freedom                                     81.4
# Trade Freedom                                         NaN
# Investment Freedom                                    NaN
# Financial Freedom                                     NaN
# Tariff Rate (%)                                       NaN
# Income Tax Rate (%)                                    15
# Corporate Tax Rate (%)                                 15
# Tax Burden % of GDP                                   NaN
# Gov't Expenditure % of GDP                           39.7
# Population (Millions)                                38.9
# GDP (Billions, PPP)                                 658.8
# GDP Growth Rate (%)                                  -0.8
# 5 Year GDP Growth Rate (%)                            4.7
# GDP per Capita (PPP)                                16954
# Unemployment (%)                                      8.2
# Inflation (%)                                         0.1
# FDI Inflow (Millions)                             -5032.4
# Public Debt (% of GDP)                                 58
#
#                                                       98                  153  \
# CountryID                                              96                 184
# Country                                             Libya             Somalia
# Region                       Middle East and North Africa  Sub-Saharan Africa
# World Rank                                            NaN                 NaN
# Region Rank                                           NaN                 NaN
# 2019 Score                                            NaN                 NaN
# Property Rights                                       7.6                33.7
# Judical Effectiveness                                24.4                26.6
# Government Integrity                                 15.8                 7.9
# Tax Burden                                            NaN                 NaN
# Gov't Spending                                          0                 NaN
# Fiscal Health                                          20                 NaN
# Business Freedom                                     40.2                31.7
# Labor Freedom                                        51.3                 NaN
# Monetary Freedom                                     52.8                 NaN
# Trade Freedom                                         NaN                 NaN
# Investment Freedom                                      5                 NaN
# Financial Freedom                                     NaN                 NaN
# Tariff Rate (%)                                       NaN                 NaN
# Income Tax Rate (%)                                    10                 NaN
# Corporate Tax Rate (%)                                 20                 NaN
# Tax Burden % of GDP                                   NaN                 NaN
# Gov't Expenditure % of GDP                          139.2                 NaN
# Population (Millions)                                 6.4                14.3
# GDP (Billions, PPP)                                  64.4                18.7
# GDP Growth Rate (%)                                  70.8                 1.8
# 5 Year GDP Growth Rate (%)                           -7.9                 2.2
# GDP per Capita (PPP)                                 9986                 NaN
# Unemployment (%)                                     17.7                   6
# Inflation (%)                                          28                 NaN
# FDI Inflow (Millions)                                 NaN                 384
# Public Debt (% of GDP)                                4.7                 NaN
#
#                                                       161  \
# CountryID                                             159
# Country                                             Syria
# Region                       Middle East and North Africa
# World Rank                                            NaN
# Region Rank                                           NaN
# 2019 Score                                            NaN
# Property Rights                                        37
# Judical Effectiveness                                24.4
# Government Integrity                                 20.3
# Tax Burden                                            NaN
# Gov't Spending                                        NaN
# Fiscal Health                                         NaN
# Business Freedom                                     49.6
# Labor Freedom                                        58.2
# Monetary Freedom                                     48.3
# Trade Freedom                                          47
# Investment Freedom                                      0
# Financial Freedom                                     NaN
# Tariff Rate (%)                                      16.5
# Income Tax Rate (%)                                    22
# Corporate Tax Rate (%)                                 28
# Tax Burden % of GDP                                   NaN
# Gov't Expenditure % of GDP                            NaN
# Population (Millions)                                18.4
# GDP (Billions, PPP)                                   NaN
# GDP Growth Rate (%)                                   NaN
# 5 Year GDP Growth Rate (%)                            NaN
# GDP per Capita (PPP)                                  NaN
# Unemployment (%)                                     14.9
# Inflation (%)                                         NaN
# FDI Inflow (Millions)                                 NaN
# Public Debt (% of GDP)                                NaN
#
#                                                       183
# CountryID                                             181
# Country                                             Yemen
# Region                       Middle East and North Africa
# World Rank                                            NaN
# Region Rank                                           NaN
# 2019 Score                                            NaN
# Property Rights                                      19.6
# Judical Effectiveness                                22.2
# Government Integrity                                 20.3
# Tax Burden                                            NaN
# Gov't Spending                                       83.7
# Fiscal Health                                           0
# Business Freedom                                     45.1
# Labor Freedom                                        49.8
# Monetary Freedom                                     61.5
# Trade Freedom                                        71.4
# Investment Freedom                                     50
# Financial Freedom                                     NaN
# Tariff Rate (%)                                       4.3
# Income Tax Rate (%)                                   NaN
# Corporate Tax Rate (%)                                NaN
# Tax Burden % of GDP                                   NaN
# Gov't Expenditure % of GDP                            NaN
# Population (Millions)                                  30
# GDP (Billions, PPP)                                  38.6
# GDP Growth Rate (%)                                 -13.8
# 5 Year GDP Growth Rate (%)                          -16.1
# GDP per Capita (PPP)                                 1287
# Unemployment (%)                                       14
# Inflation (%)                                         4.9
# FDI Inflow (Millions)                              -269.9
# Public Debt (% of GDP)                                141

# %% [markdown]
# Based from the statistical summary a handful of variables that are skewed, so I was use median for imputation of missing data. Drop ID variable, categorical variables, and variables with little correlation to the others.

# %%
drop_colums = ['CountryID','Country','Region', 'Public Debt (% of GDP)', 'FDI Inflow (Millions)',
              'Inflation (%)', 'Unemployment (%)', '5 Year GDP Growth Rate (%)', 'GDP Growth Rate (%)',
               'Population (Millions)', 'Tax Burden', "Gov't Spending", 'GDP (Billions, PPP)']
data_drop = data.drop(columns=drop_colums)
imputer = SimpleImputer(missing_values=np.nan, strategy='median') # replace missing with median


cols = list(data_drop)   # Keep column names
data_trans = imputer.fit_transform(data_drop) # replace missing with median but lose column names
df_ = pd.DataFrame(data_trans) # make array data base again
df_.columns = cols  # add column names back
df_.T
# Out:
#                                 0        1        2       3        4    \
# World Rank                    152.0     52.0    171.0   156.0    148.0
# Region Rank                    39.0     27.0     14.0    33.0     26.0
# 2019 Score                     51.5     66.5     46.2    50.6     52.2
# Property Rights                19.6     54.8     31.6    35.9     47.8
# Judical Effectiveness          29.6     30.6     36.2    26.6     44.5
# Government Integrity           25.2     40.4     28.9    20.5     33.5
# Fiscal Health                  99.3     80.6     18.7    58.2     33.0
# Business Freedom               49.2     69.3     61.6    55.7     56.4
# Labor Freedom                  60.4     52.7     49.9    58.8     46.9
# Monetary Freedom               76.7     81.5     74.9    55.4     60.2
# Trade Freedom                  66.0     87.8     67.4    61.2     70.0
# Investment Freedom             10.0     70.0     30.0    30.0     55.0
# Financial Freedom              10.0     70.0     30.0    40.0     60.0
# Tariff Rate (%)                 7.0      1.1      8.8     9.4      7.5
# Income Tax Rate (%)            20.0     23.0     35.0    17.0     35.0
# Corporate Tax Rate (%)         20.0     15.0     23.0    30.0     30.0
# Tax Burden % of GDP             5.0     24.9     24.5    20.6     30.8
# Gov't Expenditure % of GDP     25.6     29.5     41.4    25.3     41.0
# GDP per Capita (PPP)         1958.0  12507.0  15237.0  6753.0  20876.0
#
#                                 5        6        7        8        9    ...  \
# World Rank                     47.0      5.0     31.0     60.0     76.0  ...
# Region Rank                    24.0      4.0     16.0     13.0     15.0  ...
# 2019 Score                     67.7     80.9     72.0     65.4     62.9  ...
# Property Rights                57.2     79.1     84.2     59.1     42.2  ...
# Judical Effectiveness          46.3     86.5     71.3     53.1     46.9  ...
# Government Integrity           38.6     79.9     77.4     44.7     43.7  ...
# Fiscal Health                  53.0     86.2     85.5     89.4     65.7  ...
# Business Freedom               78.3     88.3     74.9     69.5     68.5  ...
# Labor Freedom                  71.4     84.1     68.7     63.9     67.5  ...
# Monetary Freedom               77.8     86.6     81.5     63.0     78.1  ...
# Trade Freedom                  80.8     87.6     86.0     74.6     47.8  ...
# Investment Freedom             75.0     80.0     90.0     60.0     50.0  ...
# Financial Freedom              70.0     90.0     70.0     60.0     60.0  ...
# Tariff Rate (%)                 2.1      1.2      2.0      5.2     18.6  ...
# Income Tax Rate (%)            26.0     45.0     50.0     25.0      0.0  ...
# Corporate Tax Rate (%)         20.0     30.0     25.0     20.0      0.0  ...
# Tax Burden % of GDP            21.3     28.2     42.7     15.0     16.3  ...
# Gov't Expenditure % of GDP     26.4     36.5     50.2     36.7     21.0  ...
# GDP per Capita (PPP)         9456.0  50334.0  49869.0  17492.0  31139.0  ...
#
#                                  174      175      176     177     178  \
# World Rank                       7.0     12.0     40.0   140.0   116.0
# Region Rank                      3.0      2.0      6.0    36.0    26.0
# 2019 Score                      78.9     76.8     68.6    53.3    56.4
# Property Rights                 92.3     79.3     68.3    49.8    65.9
# Judical Effectiveness           85.9     78.6     58.9    34.3    36.4
# Government Integrity            83.8     77.4     69.2    25.2    51.9
# Fiscal Health                   68.6     53.1     69.9    98.7    15.3
# Business Freedom                92.9     83.8     74.3    72.5    52.4
# Labor Freedom                   73.5     89.4     71.9    58.7    58.8
# Monetary Freedom                81.2     76.6     72.9    58.9    75.0
# Trade Freedom                   86.0     86.6     78.6    62.6    64.4
# Investment Freedom              90.0     85.0     85.0    10.0    65.0
# Financial Freedom               80.0     80.0     30.0    10.0    40.0
# Tariff Rate (%)                  2.0      1.7      5.7     8.7     7.8
# Income Tax Rate (%)             45.0     37.0     30.0    22.0     0.0
# Corporate Tax Rate (%)          20.0     21.0     25.0     7.5     0.0
# Tax Burden % of GDP             33.2     26.0     27.4    18.2    16.3
# Gov't Expenditure % of GDP      41.6     37.8     32.9    33.0    39.1
# GDP per Capita (PPP)         44118.0  59501.0  22371.0  6929.0  2739.0
#
#                                  179     180     181     182     183
# World Rank                     179.0   128.0    90.0   138.0   175.0
# Region Rank                     32.0    30.0    19.0    27.0    45.0
# 2019 Score                      25.9    55.3    60.8    53.6    40.4
# Property Rights                  7.6    49.8    19.6    45.0    29.7
# Judical Effectiveness           13.1    40.3    22.2    35.6    24.8
# Government Integrity             7.9    34.0    20.3    32.3    15.8
# Fiscal Health                   17.6    40.7     0.0    12.3    23.7
# Business Freedom                33.9    63.5    45.1    71.1    33.4
# Labor Freedom                   28.0    62.8    49.8    46.0    43.3
# Monetary Freedom                 0.0    68.9    61.5    70.3    72.4
# Trade Freedom                   60.0    79.2    71.4    72.6    70.0
# Investment Freedom               0.0    30.0    50.0    55.0    25.0
# Financial Freedom               10.0    40.0    50.0    50.0    10.0
# Tariff Rate (%)                 10.0     2.9     4.3     6.2     5.0
# Income Tax Rate (%)             34.0    35.0    30.0    35.0    51.5
# Corporate Tax Rate (%)          34.0    22.0    25.0    35.0    25.0
# Tax Burden % of GDP             14.9    18.0    20.7    17.9    22.3
# Gov't Expenditure % of GDP      37.4    29.4    32.3    25.8    29.2
# GDP per Capita (PPP)         12114.0  6913.0  1287.0  3996.0  2283.0
#
# [19 rows x 184 columns]

# %% [markdown]
# Normalize values so no one variable can out weight the other.

# %%
df_X = df_.drop(['World Rank', 'Region Rank'], axis = 1)#World rank is like a depended variable
                                              #Region rank is like a depended variable too
df_Y = df_[['World Rank']]


data_score = df_X.apply(zscore)

# %% [markdown]
# ### Principal Component Analysis

# %% [markdown]
# - Objective: Select the minimum number of principal components that can explain at least 95% of variance

# %%
Cov_Matrix = np.cov(data_score.T)
print('Covariance Matrix \n', Cov_Matrix)
# Out:
# Covariance Matrix
#  [[ 1.00546448  0.84300548  0.79431938  0.78264305  0.53723359  0.77770153
#    0.53499044  0.55108482  0.69898003  0.72585579  0.79325294 -0.55343106
#    0.00954972 -0.32790968  0.30004503  0.0057529   0.63807798]
#  [ 0.84300548  1.00546448  0.82769416  0.85946434  0.33883695  0.79227807
#    0.42745399  0.50285959  0.67616277  0.66369322  0.70770262 -0.5385491
#    0.15318782 -0.29781212  0.47932263  0.13240567  0.69029877]
#  [ 0.79431938  0.82769416  1.00546448  0.88666209  0.31187412  0.72237464
#    0.43721667  0.41666627  0.5486913   0.53398759  0.58154453 -0.42036161
#    0.18054156 -0.21730272  0.35636519  0.09247058  0.64121497]
#  [ 0.78264305  0.85946434  0.88666209  1.00546448  0.30078493  0.73507954
#    0.40961617  0.43855893  0.56785179  0.57790583  0.61235964 -0.44009081
#    0.22179519 -0.25248485  0.41923482  0.19925399  0.70489495]
#  [ 0.53723359  0.33883695  0.31187412  0.30078493  1.00546448  0.30582922
#    0.14520856  0.27419843  0.25840346  0.24539874  0.2311369  -0.20351094
#    0.07279311 -0.06332377  0.15448078 -0.09636133  0.23549139]
#  [ 0.77770153  0.79227807  0.72237464  0.73507954  0.30582922  1.00546448
#    0.47043207  0.40947752  0.60473481  0.54619663  0.58662386 -0.48099355
#   -0.00201105 -0.34264511  0.38613005  0.10086146  0.54329601]
#  [ 0.53499044  0.42745399  0.43721667  0.40961617  0.14520856  0.47043207
#    1.00546448  0.26225023  0.31305711  0.25421468  0.29286651 -0.24698878
#   -0.16843116 -0.17884991  0.02057011 -0.01974194  0.26534299]
#  [ 0.55108482  0.50285959  0.41666627  0.43855893  0.27419843  0.40947752
#    0.26225023  1.00546448  0.39106556  0.59505958  0.4651346  -0.29322092
#    0.08943303 -0.20347331  0.29146299  0.04633048  0.30916967]
#  [ 0.69898003  0.67616277  0.5486913   0.56785179  0.25840346  0.60473481
#    0.31305711  0.39106556  1.00546448  0.58375754  0.62498284 -0.95650024
#   -0.02997508 -0.33823966  0.38319123  0.16808295  0.5584718 ]
#  [ 0.72585579  0.66369322  0.53398759  0.57790583  0.24539874  0.54619663
#    0.25421468  0.59505958  0.58375754  1.00546448  0.77969906 -0.42586588
#    0.17720256 -0.14996375  0.44913168  0.00882717  0.47396242]
#  [ 0.79325294  0.70770262  0.58154453  0.61235964  0.2311369   0.58662386
#    0.29286651  0.4651346   0.62498284  0.77969906  1.00546448 -0.48464658
#    0.09349627 -0.25582099  0.39173332  0.12253125  0.58986575]
#  [-0.55343106 -0.5385491  -0.42036161 -0.44009081 -0.20351094 -0.48099355
#   -0.24698878 -0.29322092 -0.95650024 -0.42586588 -0.48464658  1.00546448
#    0.06803457  0.31736884 -0.33147518 -0.17045433 -0.46325406]
#  [ 0.00954972  0.15318782  0.18054156  0.22179519  0.07279311 -0.00201105
#   -0.16843116  0.08943303 -0.02997508  0.17720256  0.09349627  0.06803457
#    1.00546448  0.5587359   0.34719938  0.01666611 -0.02641756]
#  [-0.32790968 -0.29781212 -0.21730272 -0.25248485 -0.06332377 -0.34264511
#   -0.17884991 -0.20347331 -0.33823966 -0.14996375 -0.25582099  0.31736884
#    0.5587359   1.00546448 -0.06026384 -0.1749008  -0.34018938]
#  [ 0.30004503  0.47932263  0.35636519  0.41923482  0.15448078  0.38613005
#    0.02057011  0.29146299  0.38319123  0.44913168  0.39173332 -0.33147518
#    0.34719938 -0.06026384  1.00546448  0.48309987  0.28312465]
#  [ 0.0057529   0.13240567  0.09247058  0.19925399 -0.09636133  0.10086146
#   -0.01974194  0.04633048  0.16808295  0.00882717  0.12253125 -0.17045433
#    0.01666611 -0.1749008   0.48309987  1.00546448  0.17383663]
#  [ 0.63807798  0.69029877  0.64121497  0.70489495  0.23549139  0.54329601
#    0.26534299  0.30916967  0.5584718   0.47396242  0.58986575 -0.46325406
#   -0.02641756 -0.34018938  0.28312465  0.17383663  1.00546448]]

# %%
eig_vals, eig_vecs = np.linalg.eig(Cov_Matrix)

# %%
Tot = sum(eig_vals)
var_exp = [( i /Tot ) * 100 for i in sorted(eig_vals, reverse=True)]
cum_var_exp = np.cumsum(var_exp)

print(extra['Bold'],extra['Blue'],extra['Underline'],"\n Cumulative Variance Explained")
print("\n")
print(extra['End'],cum_var_exp) # it seems 11 PC will explain at least 95 percent variability.
# Out:
#
#  Cumulative Variance Explained
#
#
#  [ 46.42159623  57.09067483  65.84520849  71.96265839  77.13666147
#   82.1371319   86.50774069  89.49277793  92.31792546  94.22904779
#   95.92717352  97.25292265  98.29354212  99.04968417  99.59893763
#   99.85372788 100.        ]

# %%
plt.plot(cum_var_exp)
plt.axvline(x=11, color = 'red')
plt.axhline(y=95,color = 'red')
plt.ylabel('Cum of variation explained')
plt.xlabel('Eigen Value')
plt.show()

# %% [markdown]
# It appears that 11 principal componetns can explain 95 percent of the variation.

# %% [markdown]
# - Transform the data to 11 principal components

# %%
pca11 = PCA(n_components=11)
pca11.fit(data_score)

print(pca11.explained_variance_ratio_)
Xpca = pca11.transform(data_score)
# Out:
# [0.46421596 0.10669079 0.08754534 0.0611745  0.05174003 0.0500047
#  0.04370609 0.02985037 0.02825148 0.01911122 0.01698126]

# %%
pca11 = PCA(n_components=3) #        Transform the data with only three principle components,
pca11.fit(data_score)       #        since those components explain a majority of the variability.
pca_X = pca11.transform(data_score)
pcaX = pd.DataFrame(pca_X)

# %%
plt.scatter(x=pcaX[[0]],y= df_Y)
plt.ylabel('Ecomomic Freedom Rank')
plt.xlabel('PC1')
plt.show()

# %%
plt.scatter(x=pcaX[[1]],y= df_Y)
plt.ylabel('Ecomomic Freedom Rank')
plt.xlabel('PC2')
plt.show()

# %%
plt.scatter(x=pcaX[[2]],y= df_Y)
plt.ylabel('Ecomomic Freedom Rank')
plt.xlabel('PC3')
plt.show()

# %% [markdown]
# ## Perform clustering

# %%
clusters=range(1,20) ############## have a range of possiable clusters
meanDistortions=[]

for k in clusters:
    model=KMeans(n_clusters=k)
    model.fit(df_X)
    prediction=model.predict(df_X)
    meanDistortions.append(sum(np.min(cdist(df_X, model.cluster_centers_, 'euclidean'), axis=1)) / df_X
                           .shape[0])


plt.plot(clusters, meanDistortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Average distortion')
plt.title('Elbow Method plot')
# Out:
# Text(0.5, 1.0, 'Elbow Method plot')

# %%
clusters=range(1,10) ############## make range smaller
meanDistortions=[]

for k in clusters:
    model=KMeans(n_clusters=k)
    model.fit(df_X)
    prediction=model.predict(df_X)
    meanDistortions.append(sum(np.min(cdist(df_X, model.cluster_centers_, 'euclidean'), axis=1)) / df_X
                           .shape[0])


plt.plot(clusters, meanDistortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Average distortion')
plt.title('Elbow Method plot')
# Out:
# Text(0.5, 1.0, 'Elbow Method plot')

# %%
# Selecting 4 clusters based off of plot
kmeans = KMeans(n_clusters=4, n_init = 15, random_state= seed)

# %%
kmeans.fit(data_score)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=15, n_jobs=None, precompute_distances='auto',
#        random_state=1729, tol=0.0001, verbose=0)

# %%
centroids = kmeans.cluster_centers_

# %%
centroid_df = pd.DataFrame(centroids, columns = list(data_score) )

###### Add group to data set

df_labels = pd.DataFrame(kmeans.labels_ , columns = list(['Group'])) ########## column name

df_labels['Group'] = df_labels['Group'].astype('category')  ############## make group categorical


df_labeled = df_.join(df_labels)                        # Joining the label dataframe with the data frame.

df_A = (df_labeled.groupby(['Group'] , axis=0)).head()  # the groupby creates a groupeddataframe that needs 

df_A.head()
# Out:
#    World Rank  Region Rank  2019 Score  Property Rights  \
# 0       152.0         39.0        51.5             19.6
# 1        52.0         27.0        66.5             54.8
# 2       171.0         14.0        46.2             31.6
# 3       156.0         33.0        50.6             35.9
# 4       148.0         26.0        52.2             47.8
#
#    Judical Effectiveness  Government Integrity  Fiscal Health  \
# 0                   29.6                  25.2           99.3
# 1                   30.6                  40.4           80.6
# 2                   36.2                  28.9           18.7
# 3                   26.6                  20.5           58.2
# 4                   44.5                  33.5           33.0
#
#    Business Freedom  Labor Freedom  Monetary Freedom  Trade Freedom  \
# 0              49.2           60.4              76.7           66.0
# 1              69.3           52.7              81.5           87.8
# 2              61.6           49.9              74.9           67.4
# 3              55.7           58.8              55.4           61.2
# 4              56.4           46.9              60.2           70.0
#
#    Investment Freedom   Financial Freedom  Tariff Rate (%)  \
# 0                 10.0               10.0              7.0
# 1                 70.0               70.0              1.1
# 2                 30.0               30.0              8.8
# 3                 30.0               40.0              9.4
# 4                 55.0               60.0              7.5
#
#    Income Tax Rate (%)  Corporate Tax Rate (%)  Tax Burden % of GDP  \
# 0                 20.0                    20.0                  5.0
# 1                 23.0                    15.0                 24.9
# 2                 35.0                    23.0                 24.5
# 3                 17.0                    30.0                 20.6
# 4                 35.0                    30.0                 30.8
#
#    Gov't Expenditure % of GDP   GDP per Capita (PPP) Group
# 0                         25.6                1958.0     1
# 1                         29.5               12507.0     2
# 2                         41.4               15237.0     1
# 3                         25.3                6753.0     1
# 4                         41.0               20876.0     1

# %%
df_labeled['Group'].value_counts()  # Check counts for each group
# Out:
# 1    64
# 2    63
# 0    39
# 3    18
# Name: Group, dtype: int64

# %%
df_ec = df_labeled[['World Rank', 'Group']]
df_ec.boxplot(by = 'Group', figsize=(20, 15))

# %% [markdown]
# Group 0 is mainly made of countries with high world rank compared to the other groups. Group 1 has the lowest rank countries, while group 2 and 3 are in the middle.

# %%
df_ec = df_labeled[['GDP per Capita (PPP)', 'Group']]
df_ec.boxplot(by = 'Group', figsize=(10, 6))

# %% [markdown]
# Group 1 and 2 have lower GDP per Capita (PPP) than the other two groups.

# %%
df_ec = df_labeled[['Region Rank', 'Group']]
df_ec.boxplot(by = 'Group', figsize=(10, 6))

# %% [markdown]
# Group one seems to have more countries with higher region rank thank the other groups.

# %%
df_ec = df_labeled[['Property Rights', 'Group']]
df_ec.boxplot(by = 'Group', figsize=(10, 6))

# %% [markdown]
# Group 0 has higher property right values than the other groups. Group 1 has the lower end, and group 2 and 3 are mid range.

# %%
df_ec = df_labeled[['Trade Freedom', 'Group']]
df_ec.boxplot(by = 'Group', figsize=(10, 6))

# %% [markdown]
# Group 0 has higher trade freedom values than the other groups, with very little variability, compared to the other groups. Group 2 and 3 aren't two far behind group 0 but with much varability. Group 1 seems to be compressed with countries with lower trade freedoms.

# %%
df_ec = df_labeled[['2019 Score', 'Group']]
df_ec.boxplot(by = 'Group', figsize=(10, 6))

# %% [markdown]
# Group 0 has higher 2019 score than the other groups. Group 2 has values with in the range of 3 but not a disbursed.

# %% [markdown]
# ## Summary of findings

# %% [markdown]
# As said earlier, world rank is highly influenced by 2019 score, property rights, judicial effectiveness, government integrity, business freedom, trade freedom, investment freedom, and financial freedom.
#
# Between the five regions, they have similar ranges when it comes to economic freedom. In other words, each region has its share of well-developed countries and not so developed countries.
# One thing unexpected about this data set was its completeness. With all these countries around the world, with their different backgrounds, there isn’t that many missing observations.
#
# I found that 11 principle components explain a little over 95 percent of variability. I also found a strong correlation between PC1 and world rank. The others don't really have that strong of a correlation. It I was later to build a model to help predict economic freedom, PC1 would be a good hyperparameter.
#
# From the cluster analysis, there is a clear difference in world rank between group 0 and 1. Group 0 having more countries with a high world rank, higher property rights, and trade rights. GDP per capita is lower in groups 2 and 3 than groups 0 and 4. Since there is an overlap with groups 3 and 4, it is possible to maybe have those two groups put together in future analysis.
